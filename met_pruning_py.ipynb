# %% [markdown]
# Import data first

# %%
import pandas as pd
from os import *
from pathlib import *
from matplotlib import *

# %%
frame = pd.read_csv("test1.csv",header=None)

# %%
frame[:3]
# Out:
#            0          1          2          3          4         5   \
# 0     easting   22500.00   27500.00   32500.00   37500.00   42500.0
# 1    northing  497500.00  497500.00  497500.00  497500.00  497500.0
# 2  1958-01-01       0.04       0.03       0.02       0.01       0.0
#
#           6          7         8         9         10         11        12  \
# 0   47500.00   32500.00   37500.0   42500.0   47500.0   32500.00   37500.0
# 1  497500.00  492500.00  492500.0  492500.0  492500.0  487500.00  487500.0
# 2       0.01       0.01       0.0       0.0       0.0       0.01       0.0
#
#          13        14
# 0   42500.0   47500.0
# 1  487500.0  487500.0
# 2       0.0       0.0

# %%
frame.plot()

# %%
frame[1]
# Out:
#            0          1          2          3          4         5   \
# 0     easting   22500.00   27500.00   32500.00   37500.00   42500.0
# 1    northing  497500.00  497500.00  497500.00  497500.00  497500.0
# 2  1958-01-01       0.04       0.03       0.02       0.01       0.0
#
#           6          7         8         9         10         11        12  \
# 0   47500.00   32500.00   37500.0   42500.0   47500.0   32500.00   37500.0
# 1  497500.00  492500.00  492500.0  492500.0  492500.0  487500.00  487500.0
# 2       0.01       0.01       0.0       0.0       0.0       0.01       0.0
#
#          13        14
# 0   42500.0   47500.0
# 1  487500.0  487500.0
# 2       0.0       0.0

# %%
t = frame.T

# %%
t
# Out:
#       0         1           2           3           4           5      \
# 0   easting  northing  1958-01-01  1958-01-02  1958-01-03  1958-01-04
# 1     22500    497500        0.04        6.13        0.04        8.73
# 2     27500    497500        0.03        4.56        0.02        6.88
# 3     32500    497500        0.02        3.69        0.01        5.77
# 4     37500    497500        0.01        2.93        0.01        4.65
# 5     42500    497500           0        2.62           0        4.22
# 6     47500    497500        0.01        2.94           0         4.9
# 7     32500    492500        0.01         3.8        0.01        5.87
# 8     37500    492500           0        2.73           0         4.2
# 9     42500    492500           0        2.36           0        3.61
# 10    47500    492500           0        2.44           0        3.75
# 11    32500    487500        0.01        3.96        0.01        6.08
# ...

# %%
t.rename(columns=t[0])
# Out:
#     easting   22500.0     27500.0     32500.0     37500.0     42500.0  \
# 0   easting  northing  1958-01-01  1958-01-02  1958-01-03  1958-01-04
# 1     22500    497500        0.04        6.13        0.04        8.73
# 2     27500    497500        0.03        4.56        0.02        6.88
# 3     32500    497500        0.02        3.69        0.01        5.77
# 4     37500    497500        0.01        2.93        0.01        4.65
# 5     42500    497500           0        2.62           0        4.22
# 6     47500    497500        0.01        2.94           0         4.9
# 7     32500    492500        0.01         3.8        0.01        5.87
# 8     37500    492500           0        2.73           0         4.2
# 9     42500    492500           0        2.36           0        3.61
# 10    47500    492500           0        2.44           0        3.75
# 11    32500    487500        0.01        3.96        0.01        6.08
# ...

# %%
t2 = t.rename(columns=t.iloc[0])

# %%
t2
# Out:
#     easting  northing  1958-01-01  1958-01-02  1958-01-03  1958-01-04  \
# 0   easting  northing  1958-01-01  1958-01-02  1958-01-03  1958-01-04
# 1     22500    497500        0.04        6.13        0.04        8.73
# 2     27500    497500        0.03        4.56        0.02        6.88
# 3     32500    497500        0.02        3.69        0.01        5.77
# 4     37500    497500        0.01        2.93        0.01        4.65
# 5     42500    497500           0        2.62           0        4.22
# 6     47500    497500        0.01        2.94           0         4.9
# 7     32500    492500        0.01         3.8        0.01        5.87
# 8     37500    492500           0        2.73           0         4.2
# 9     42500    492500           0        2.36           0        3.61
# 10    47500    492500           0        2.44           0        3.75
# 11    32500    487500        0.01        3.96        0.01        6.08
# ...

# %%
t3 = t2

# %%
t3.drop(1)
# Out:
#     easting  northing  1958-01-01  1958-01-02  1958-01-03  1958-01-04  \
# 0   easting  northing  1958-01-01  1958-01-02  1958-01-03  1958-01-04
# 2     27500    497500        0.03        4.56        0.02        6.88
# 3     32500    497500        0.02        3.69        0.01        5.77
# 4     37500    497500        0.01        2.93        0.01        4.65
# 5     42500    497500           0        2.62           0        4.22
# 6     47500    497500        0.01        2.94           0         4.9
# 7     32500    492500        0.01         3.8        0.01        5.87
# 8     37500    492500           0        2.73           0         4.2
# 9     42500    492500           0        2.36           0        3.61
# 10    47500    492500           0        2.44           0        3.75
# 11    32500    487500        0.01        3.96        0.01        6.08
# 12    37500    487500           0        2.48           0        3.79
# ...

# %%
t4 = t3.drop(0)

# %%
t4[0:5]
# Out:
#   easting northing 1958-01-01 1958-01-02 1958-01-03 1958-01-04 1958-01-05  \
# 1   22500   497500       0.04       6.13       0.04       8.73      17.45
# 2   27500   497500       0.03       4.56       0.02       6.88      15.51
# 3   32500   497500       0.02       3.69       0.01       5.77      14.25
# 4   37500   497500       0.01       2.93       0.01       4.65      12.17
# 5   42500   497500          0       2.62          0       4.22      10.98
#
#   1958-01-06 1958-01-07 1958-01-08    ...     2016-12-22 2016-12-23  \
# 1      16.33       4.55      19.53    ...           7.16       17.8
# 2      14.07       3.78       16.2    ...           6.22      16.03
# 3      12.63       3.32      14.19    ...           4.64      13.04
# 4      10.63       2.76      11.79    ...            4.1      11.45
# 5       9.71       2.41      10.57    ...           3.91      12.06
#
#   2016-12-24 2016-12-25 2016-12-26 2016-12-27 2016-12-28 2016-12-29  \
# ...

# %%
t5=t4.T

# %%
t5
# Out:
#                 1       2       3       4       5       6       7       8   \
# easting      22500   27500   32500   37500   42500   47500   32500   37500
# northing    497500  497500  497500  497500  497500  497500  492500  492500
# 1958-01-01    0.04    0.03    0.02    0.01       0    0.01    0.01       0
# 1958-01-02    6.13    4.56    3.69    2.93    2.62    2.94     3.8    2.73
# 1958-01-03    0.04    0.02    0.01    0.01       0       0    0.01       0
# 1958-01-04    8.73    6.88    5.77    4.65    4.22     4.9    5.87     4.2
# 1958-01-05   17.45   15.51   14.25   12.17   10.98    11.3    16.6   12.93
# 1958-01-06   16.33   14.07   12.63   10.63    9.71   10.82   13.76   10.38
# 1958-01-07    4.55    3.78    3.32    2.76    2.41    2.26    3.95    3.09
# 1958-01-08   19.53    16.2   14.19   11.79   10.57   11.13   15.89   12.06
# 1958-01-09    15.9    13.7    12.4   10.53    9.46     9.6   14.51   11.32
# ...

# %%
start = datetime.strptime('2000-01-01','%Y-%m-%d')
for date in t5.index:
    if date != "easting" and date != "northing":
        if datetime.strptime(date,"%Y-%m-%d") < start:
            print(type(date))
            t5.drop(date,1,inplace=True)
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-2923504746b2> in <module>()
#       4         if datetime.strptime(date,"%Y-%m-%d") < start:
#       5             print(type(date))
# ----> 6             t5.drop(date,1,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
# ...

# %%
from datetime import *
datething = datetime.strptime('2016-12-30')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-32924b7a6e07> in <module>()
#       1 from datetime import *
# ----> 2 datething = datetime('2016-12-30')
#
# TypeError: an integer is required (got type str)

# %%
t5[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-05eb79c476db> in <module>()
# ----> 1 t5[1]
#
# NameError: name 't5' is not defined
