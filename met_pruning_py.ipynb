# %% [markdown]
# # A process to prune the MET office data to those values that are more recent than 1st January 2000, and converts the easting and northing column indexes into a consistent format as the headers
# ## Note that complete merge

# %% [markdown]
# ## Take in data

# %%
import pandas as pd
from os import *
from pathlib import *
from matplotlib import *

# %%
frame = pd.read_csv("test1.csv",header=None)

# %%
frame.head(3)
# Out:
#            0          1          2          3          4         5   \
# 0     easting   22500.00   27500.00   32500.00   37500.00   42500.0
# 1    northing  497500.00  497500.00  497500.00  497500.00  497500.0
# 2  1958-01-01       0.04       0.03       0.02       0.01       0.0
#
#           6          7         8         9         10         11        12  \
# 0   47500.00   32500.00   37500.0   42500.0   47500.0   32500.00   37500.0
# 1  497500.00  492500.00  492500.0  492500.0  492500.0  487500.00  487500.0
# 2       0.01       0.01       0.0       0.0       0.0       0.01       0.0
#
#          13        14
# 0   42500.0   47500.0
# 1  487500.0  487500.0
# 2       0.0       0.0

# %% [markdown]
# ## Get the Eastings and Northings into a form suitable for column names

# %%
frame.iloc[[0,1],1:]
# Out:
#          1         2         3         4         5         6         7   \
# 0   22500.0   27500.0   32500.0   37500.0   42500.0   47500.0   32500.0
# 1  497500.0  497500.0  497500.0  497500.0  497500.0  497500.0  492500.0
#
#          8         9         10        11        12        13        14
# 0   37500.0   42500.0   47500.0   32500.0   37500.0   42500.0   47500.0
# 1  492500.0  492500.0  492500.0  487500.0  487500.0  487500.0  487500.0

# %%
# using zero padding to get to length 6
uni_indexing = frame.iloc[[0,1],1:].apply(lambda x : f'{int(x.iloc[0]):06}{int(x.iloc[1]):06}',axis=0)

# %%
# multi_indexing is an intermediate stage to make proper multi indexing easier
multi_indexing = frame.iloc[[0,1],1:].apply(lambda x : (f'{int(x.iloc[0]):06}',f'{int(x.iloc[1]):06}'))

# %%
uni_indexing.head(4)
# Out:
# 1    022500497500
# 2    027500497500
# 3    032500497500
# 4    037500497500
# dtype: object

# %%
multi_indexing.head(5)
# Out:
# 1    (022500, 497500)
# 2    (027500, 497500)
# 3    (032500, 497500)
# 4    (037500, 497500)
# 5    (042500, 497500)
# dtype: object

# %%
## drop unnecessary rows
frame = frame.drop(0)
frame = frame.drop(1)

# %%
frame.head(5)

# %% [markdown]
# ## Set the indexes

# %%
frame.set_index(0,inplace=True)

# %%
frame.index.name='Date'

# %%
frame.head(5)

# %% [markdown]
# ## Set the column names

# %%
columns_uni = pd.concat([pd.Series(['Date']),uni_indexing])
columns_multi = pd.concat([pd.Series(['Date']),multi_indexing])

# %%
frame_uni = frame.copy()
frame_multi = frame.copy()
frame_uni.columns=uni_indexing
frame_multi.columns=multi_indexing

# %%
frame_uni.head(5)
# Out:
#             (022500, 497500)  (027500, 497500)  (032500, 497500)  \
# Date
# 1958-01-01              0.04              0.03              0.02
# 1958-01-02              6.13              4.56              3.69
# 1958-01-03              0.04              0.02              0.01
# 1958-01-04              8.73              6.88              5.77
# 1958-01-05             17.45             15.51             14.25
#
#             (037500, 497500)  (042500, 497500)  (047500, 497500)  \
# Date
# 1958-01-01              0.01              0.00              0.01
# 1958-01-02              2.93              2.62              2.94
# 1958-01-03              0.01              0.00              0.00
# 1958-01-04              4.65              4.22              4.90
# 1958-01-05             12.17             10.98             11.30
#
#             (032500, 492500)  (037500, 492500)  (042500, 492500)  \
# Date
# 1958-01-01              0.01              0.00              0.00
# 1958-01-02              3.80              2.73              2.36
# 1958-01-03              0.01              0.00              0.00
# 1958-01-04              5.87              4.20              3.61
# 1958-01-05             16.60             12.93             11.56
#
#             (047500, 492500)  (032500, 487500)  (037500, 487500)  \
# Date
# 1958-01-01              0.00              0.01              0.00
# 1958-01-02              2.44              3.96              2.48
# 1958-01-03              0.00              0.01              0.00
# 1958-01-04              3.75              6.08              3.79
# 1958-01-05             11.76             18.13             12.10
#
#             (042500, 487500)  (047500, 487500)
# Date
# 1958-01-01              0.00              0.00
# 1958-01-02              2.46              2.42
# 1958-01-03              0.00              0.00
# 1958-01-04              3.74              3.69
# 1958-01-05             12.21             11.98

# %%
frame_multi.head(5)

# %% [markdown]
# ## Prune the values to be only those we want

# %%
frame2 = frame.loc['2000-01-01':]

# %%
frame2.head(9)
# Out:
#             (022500, 497500)  (027500, 497500)  (032500, 497500)  \
# Date
# 2000-01-01              0.07              0.06              0.31
# 2000-01-02              2.05              1.88              1.65
# 2000-01-03              3.72              3.38              3.03
# 2000-01-04              2.92              2.52              1.55
# 2000-01-05             10.08              8.57              7.47
# 2000-01-06              4.99              3.71              2.83
# 2000-01-07             10.98             10.11              7.69
# 2000-01-08              9.57              8.29              7.66
# 2000-01-09              1.26              1.08              0.73
#
#             (037500, 497500)  (042500, 497500)  (047500, 497500)  \
# Date
# 2000-01-01              0.62              1.23              1.10
# 2000-01-02              1.76              2.02              1.94
# 2000-01-03              2.59              1.80              2.02
# 2000-01-04              1.00              0.70              0.77
# 2000-01-05              6.09              5.31              5.69
# 2000-01-06              2.52              2.89              2.67
# 2000-01-07              6.09              5.46              5.38
# 2000-01-08              6.40              5.12              5.23
# 2000-01-09              0.45              0.21              0.33
#
#             (032500, 492500)  (037500, 492500)  (042500, 492500)  \
# Date
# 2000-01-01              0.44              0.31              0.74
# 2000-01-02              2.44              2.11              1.56
# 2000-01-03              4.13              3.52              2.41
# 2000-01-04              1.45              1.01              0.64
# 2000-01-05              7.93              5.86              5.20
# 2000-01-06              3.18              2.42              1.72
# 2000-01-07              8.19              6.25              4.26
# 2000-01-08              9.45              7.75              4.93
# 2000-01-09              0.64              0.40              0.21
#
#             (047500, 492500)  (032500, 487500)  (037500, 487500)  \
# Date
# 2000-01-01              0.86              0.54              0.41
# 2000-01-02              1.45              2.60              1.81
# 2000-01-03              2.13              4.40              3.03
# 2000-01-04              0.59              1.47              0.86
# 2000-01-05              5.20              8.47              5.43
# 2000-01-06              1.56              3.29              2.06
# 2000-01-07              3.78              8.45              5.33
# 2000-01-08              4.18              9.88              6.51
# 2000-01-09              0.22              0.66              0.34
#
#             (042500, 487500)  (047500, 487500)
# Date
# 2000-01-01              1.06              1.00
# 2000-01-02              1.39              1.37
# 2000-01-03              2.38              2.31
# 2000-01-04              0.41              0.43
# 2000-01-05              5.51              5.38
# 2000-01-06              1.11              1.16
# 2000-01-07              3.12              3.17
# 2000-01-08              3.81              3.81
# 2000-01-09              0.01              0.05

# %% [markdown]
# ## Save to file for future use

# %% [markdown]
# ## Merge with other files of same type

# %% [markdown]
# ## Merge with files containing other information
