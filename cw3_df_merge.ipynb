# %%
import pandas as pd

# %%
traffic_data = pd.read_csv('Raw_count_data_major_roads.csv')
df1 = pd.DataFrame(traffic_data)
#df1 = df1.loc[df1['Estimation_method'] == 'Counted']
df1 = df1.rename(columns={'S Ref E': 'easting', 'S Ref N': 'northing'})
df1['easting'] = df1['easting'].astype('str')
df1['northing'] = df1['northing'].astype('str')

# %%
df1.head(3)
# Out:
#   Region Name (GO) ONS LACode       ONS LA Name    CP easting northing  \
# 0    East Midlands  E10000021  Northamptonshire  6004  458354   270523
# 1    East Midlands  E10000021  Northamptonshire  6004  458354   270523
# 2    East Midlands  E10000021  Northamptonshire  6004  458354   270523
#
#    S Ref Latitude  S Ref Longitude Road A-Junction   ...    BUS  LGV  HGVR2  \
# 0       52.329706         -1.14512   M1         17   ...      3  314  169.0
# 1       52.329706         -1.14512   M1         17   ...      3  231  148.0
# 2       52.329706         -1.14512   M1         17   ...     11  245  175.0
#
#    HGVR3  HGVR4 HGVA3 HGVA5  HGVA6    HGV     AMV
# 0     22   10.0  82.0   198  135.0  616.0  3353.0
# 1     16   22.0  64.0   180  109.0  539.0  3297.0
# 2     14   25.0  65.0   195  116.0  590.0  2730.0
#
# [3 rows x 33 columns]

# %%
weather_data = pd.read_csv('weather_example.csv', skiprows = 0)
df2 = pd.DataFrame(weather_data)
df2 = df2.T
df2.reset_index(level = 0, drop=False, inplace=True)
df2.columns = df2.iloc[0]
df2 = df2.drop(df2.index[0])
df2.columns[2:].astype('datetime64[ns]')
df2.iloc[:,0:2].astype('float')
date_range = df2.columns >= '2000-03-17'
df2 = df2.iloc[:, date_range]
df2.head(3)
# Out:
# 0 easting northing 2000-03-17 2000-03-18 2000-03-19 2000-03-20 2000-03-21  \
# 1   22500   497500       9.78       9.61      11.91       9.66       9.22
# 2   27500   497500      10.81      10.44      12.98      10.69      10.37
# 3   32500   497500      11.71      11.39      13.89      11.64       11.4
#
# 0 2000-03-22 2000-03-23 2000-03-24    ...     2016-12-22 2016-12-23  \
# 1       6.59       7.51       7.26    ...           6.88       8.26
# 2       7.88       8.69       8.45    ...              8       9.26
# 3       9.26       9.76       9.51    ...           8.92      10.07
#
# 0 2016-12-24 2016-12-25 2016-12-26 2016-12-27 2016-12-28 2016-12-29  \
# 1      10.96      11.16       5.03        5.4       5.96      10.36
# 2      11.81      12.03        6.1       5.97        6.8      10.96
# 3      12.46      12.68          7       6.41       7.48      11.41
#
# 0 2016-12-30 2016-12-31
# 1      11.12       9.61
# 2      11.86      10.52
# 3      12.41      11.21
#
# ...

# %%
df2['easting'] = df2['easting'].astype(str)
df2['northing'] = df2['northing'].astype(str)

# %%
df2['id'] = df2['easting'] + df2['northing']

# %%
df3 = df2.drop(['easting','northing'], axis = 1)

# %%
df3
# Out:
# 0  2000-03-17 2000-03-18 2000-03-19 2000-03-20 2000-03-21 2000-03-22  \
# 1        9.78       9.61      11.91       9.66       9.22       6.59
# 2       10.81      10.44      12.98      10.69      10.37       7.88
# 3       11.71      11.39      13.89      11.64       11.4       9.26
# 4        11.7      11.74      13.73      11.72      11.41       9.94
# 5       11.52      11.98      13.35      11.61      11.24      10.44
# 6       11.32      11.78       13.2      11.41      11.06      10.02
# 7       10.98       10.9       13.1      10.94      10.67       8.56
# 8       11.52      11.56      13.59      11.52      11.28       9.58
# 9       11.66      11.88      13.68      11.72      11.48      10.09
# 10      11.72      11.97      13.79      11.81       11.6      10.08
# 11       9.14       9.55       11.1        9.1       8.67       6.49
# 12      11.61      11.52       13.8      11.61      11.45       9.42
# 13      11.72      11.76      13.91      11.78      11.66       9.73
# ...

# %%
dict1 = {'ID': '27749622',
       'Date': ('2000-01-03', '1996-08-09'),
       'temp': (59, 84),}

# %%
dict1
# Out:
# {'ID': '27749622', 'Date': ('2000-01-03', '1996-08-09'), 'temp': (59, 84)}

# %%
fr = pd.DataFrame(dict1)

# %%
fr
# Out:
#          ID        Date  temp
# 0  27749622  2000-01-03    59
# 1  27749622  1996-08-09    84

# %%
id_list = df3['id'].tolist()

# %%
date_list = df3.columns.tolist()

# %%
temp_list = df3.drop(['id'], axis=1)

# %%
temp_list2 = temp_list.as_matrix()
# Out:
# C:\Apps\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
temp_list2
# Out:
# array([[9.78, 9.61, 11.91, ..., 10.36, 11.12, 9.61],
#        [10.81, 10.44, 12.98, ..., 10.96, 11.86, 10.52],
#        [11.71, 11.39, 13.89, ..., 11.41, 12.41, 11.21],
#        ...,
#        [11.61, 11.52, 13.8, ..., 11.21, 12.16, 10.93],
#        [11.72, 11.76, 13.91, ..., 11.24, 12.29, 11.08],
#        [11.89, 11.94, 14.14, ..., 11.25, 12.39, 11.17]], dtype=object)

# %%
# for i in id_list:
# #      new_dict = {'ID': i,
# #                 'Dates': date_list}
# # new_df = pd.DataFrame(new_dict)
# # new_df

# for i in id_list:
#     for temp in i:
#             new_dict = {'Id': i,
#                         'Date': (date_list),
#                         'temp': (temp)}
df3.T
# Out:
#                        1              2              3              4   \
# 0
# 2000-03-17           9.78          10.81          11.71           11.7
# 2000-03-18           9.61          10.44          11.39          11.74
# 2000-03-19          11.91          12.98          13.89          13.73
# 2000-03-20           9.66          10.69          11.64          11.72
# 2000-03-21           9.22          10.37           11.4          11.41
# 2000-03-22           6.59           7.88           9.26           9.94
# 2000-03-23           7.51           8.69           9.76           9.89
# 2000-03-24           7.26           8.45           9.51           9.35
# 2000-03-25           7.46           8.57           9.52            9.4
# 2000-03-26           8.09           9.31          10.52          10.77
# 2000-03-27          10.14          11.53          12.95          13.47
# 2000-03-28           8.95          10.17          11.44          11.99
# ...

# %%
ew_df = pd.DataFrame(new_dict)`
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-04caa0423caf> in <module>()
# ----> 1 ew_df = pd.DataFrame(new_dict)
#
# C:\Apps\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# C:\Apps\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
# ...

# %%
for idx, i in enumerate(id_list):
    id_list[idx].append(date_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-a39601c47b14> in <module>()
#       1 for idx, i in enumerate(id_list):
# ----> 2     id_list[idx].append(date_list)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
for idx, i in enumerate(id_list):
    id_list[idx]

# %%
dict9 = {'ID': id_list}

# %%
for key, value in dict9.items():
    print(key, value)
# Out:
# ID ['22500497500.0', '27500497500.0', '32500497500.0', '37500497500.0', '42500497500.0', '47500497500.0', '32500.1492500.0', '37500.1492500.0', '42500.1492500.0', '47500.1492500.0', '32500.2487500.0', '37500.2487500.0', '42500.2487500.0', '47500.2487500.0']

# %%
g = pd.DataFrame.from_dict(dict9, orient='index')

# %%
from collections import defaultdict
dates_dict = defaultdict(date_list)
for key, date in dict9:
    dates_dict[key].append(date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-195-7aceb7d4baa1> in <module>()
#       1 from collections import defaultdict
# ----> 2 dates_dict = defaultdict(date_list)
#       3 for key, date in dict9:
#       4     dates_dict[key].append(date)
#
# TypeError: first argument must be callable or None

# %%
# Out:
# defaultdict(list, {})
